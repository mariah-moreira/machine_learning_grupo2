# %% [markdown]
# **Modelagem**
# - Selecionar modelos a serem utilizados
# - Explicar potenciais benefícios
# - Mostrar principais métricas
# - Conclusões iniciais

# %% [markdown]
# #Processo de modelagem dos dados.
#
# O processo consiste em:
#
# - 0) Fazer todo o processo de limpeza e avaliação da base, EDA, etc., etc.
#
#
# - 1) Importar a **classe do algoritmo que se deseja treinar**
#     - Usaremos quase sempre a biblioteca [scikit-learn](https://scikit-learn.org/stable/)
#
#
# - 2) Instanciar a classe do algoritmo, **escolhendo os hiperparâmetros desejados**
#     - Para a primeira versão do modelo, pode ser uma boa escolha utilizar os parâmetros default;
#     - Veremos mais pra frente como escolher os parâmetros adequadamente;
#
#
# - 3) Separe os dados em **dados de treino** e **dados de teste**.
#     - Em alguns casos, pode ser interessante criar também um conjunto de **dados de validação**
#     - Para fazer a separação, usamos o [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#
#
# - 4) Treine o modelo, usando **os dados de treino**
#
#
# - 5) Use o modelo treinado para **fazer previsões** usando os **dados de teste** (ou **de validação**)
#
#
# - 6) **Avalie a performance do modelo com base nas previsões acima**
#
#
# - 7) Se necessário, reinicie o ciclo!
#
#
# - 8) Quando o modelo estiver suficientemente bom, faça o **deploy**

# %% [markdown]
# #0 - Importando e instalando as bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import re
from seaborn.widgets import cubehelix_palette
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from mlxtend.plotting import plot_confusion_matrix
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from pprint import pprint
from sklearn.model_selection import GridSearchCV

# %%
#Paleta de cores escolhida
paleta = sns.cubehelix_palette()

# %% [markdown]
# #1 - Processando os dados

# %%
#Importando dados feito o tratamento de nulos, inconsistência de dados, união das bases e mudança de nome.
bd_data_clean = './Credit_card_clean.csv'

df = pd.read_csv(bd_data_clean)

# %%
#Observando as primeiras linhas dos dados
df.head().T
# Out:
#                                         0                     1  \
# id                                5008827               5009744
# genero                                  M                     F
# carro                                   Y                     Y
# bens_propriedade                        Y                     N
# filhos                                  0                     0
# renda_anual                      180000.0              315000.0
# tipo_renda                    Pensionista   Associado Comercial
# escolaridade              Ensino superior       Ensino superior
# estado_civil                       Casado                Casado
# estilo_vida              Casa/Apartamento      Casa/Apartamento
# contar_aniverisario              -18772.0              -13557.0
# desempregado                       365243                  -586
# celular                                 1                     1
# telefone_comercial                      0                     1
# telefone                                0                     1
# email_id                                0                     0
# tipo_ocupação        Prefiro não informar  Prefiro não informar
# tamanho_familia                         2                     2
# status                                  1                     1
#
#                                         2                     3  \
# id                                5009746               5009749
# genero                                  F                     F
# carro                                   Y                     Y
# bens_propriedade                        N                     N
# filhos                                  0                     0
# renda_anual                      315000.0             172243.04
# tipo_renda            Associado Comercial   Associado Comercial
# escolaridade              Ensino superior       Ensino superior
# estado_civil                       Casado                Casado
# estilo_vida              Casa/Apartamento      Casa/Apartamento
# contar_aniverisario                   NaN              -13557.0
# desempregado                         -586                  -586
# celular                                 1                     1
# telefone_comercial                      1                     1
# telefone                                1                     1
# email_id                                0                     0
# tipo_ocupação        Prefiro não informar  Prefiro não informar
# tamanho_familia                         2                     2
# status                                  1                     1
#
#                                         4
# id                                5009752
# genero                                  F
# carro                                   Y
# bens_propriedade                        N
# filhos                                  0
# renda_anual                      315000.0
# tipo_renda            Associado Comercial
# escolaridade              Ensino superior
# estado_civil                       Casado
# estilo_vida              Casa/Apartamento
# contar_aniverisario              -13557.0
# desempregado                         -586
# celular                                 1
# telefone_comercial                      1
# telefone                                1
# email_id                                0
# tipo_ocupação        Prefiro não informar
# tamanho_familia                         2
# status                                  1

# %%
# Algumas métricas estatísticas.
df.describe().T
# Out:
#                       count          mean            std        min  \
# id                   1541.0  5.078979e+06   41671.365842  5008827.0
# filhos               1541.0  4.133679e-01       0.777811        0.0
# renda_anual          1541.0  1.908141e+05  112153.974398    33750.0
# contar_aniverisario  1519.0 -1.604791e+04    4228.635700   -24946.0
# desempregado         1541.0  5.940589e+04  137847.216798   -14887.0
# celular              1541.0  1.000000e+00       0.000000        1.0
# telefone_comercial   1541.0  2.083063e-01       0.406229        0.0
# telefone             1541.0  3.082414e-01       0.461917        0.0
# email_id             1541.0  9.214796e-02       0.289329        0.0
# tamanho_familia      1541.0  2.162232e+00       0.948492        1.0
# status               1541.0  1.103180e-01       0.313387        0.0
#
#                            25%        50%        75%        max
# id                   5045113.0  5078924.0  5115671.0  5150412.0
# filhos                     0.0        0.0        1.0       14.0
# renda_anual           121500.0   171000.0   225000.0  1575000.0
# contar_aniverisario   -19561.5   -15702.0   -12417.5    -7705.0
# desempregado           -3173.0    -1563.0     -431.0   365243.0
# celular                    1.0        1.0        1.0        1.0
# telefone_comercial         0.0        0.0        0.0        1.0
# telefone                   0.0        0.0        1.0        1.0
# email_id                   0.0        0.0        0.0        1.0
# tamanho_familia            2.0        2.0        3.0       15.0
# status                     0.0        0.0        0.0        1.0

# %%
# Observando os dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541 entries, 0 to 1540
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1541 non-null   int64
#  1   genero               1541 non-null   object
#  2   carro                1541 non-null   object
#  3   bens_propriedade     1541 non-null   object
#  4   filhos               1541 non-null   int64
#  5   renda_anual          1541 non-null   float64
#  6   tipo_renda           1541 non-null   object
#  7   escolaridade         1541 non-null   object
#  8   estado_civil         1541 non-null   object
#  9   estilo_vida          1541 non-null   object
#  10  contar_aniverisario  1519 non-null   float64
#  11  desempregado         1541 non-null   int64
#  12  celular              1541 non-null   int64
#  13  telefone_comercial   1541 non-null   int64
#  14  telefone             1541 non-null   int64
#  15  email_id             1541 non-null   int64
#  16  tipo_ocupação        1541 non-null   object
#  17  tamanho_familia      1541 non-null   int64
#  18  status               1541 non-null   int64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 228.9+ KB

# %% [markdown]
# #2 - Tratamento para usar os modelos de Machine Learning

# %%
# Definindo a media para aplicar nos nulos na coluna "contar_aniversario"
cols_media = ['contar_aniverisario']
fill_media = SimpleImputer(missing_values=np.nan, strategy='mean')
fill_media.fit(df[cols_media])
df[cols_media] = fill_media.transform(df[cols_media])

# %%
# contar_aniverisario tranformando em idade e excluindo coluna
df["idade"] = df["contar_aniverisario"].apply(lambda x: abs(int(x))/365)
df = df.drop("contar_aniverisario", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541 entries, 0 to 1540
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1541 non-null   int64
#  1   genero              1541 non-null   object
#  2   carro               1541 non-null   object
#  3   bens_propriedade    1541 non-null   object
#  4   filhos              1541 non-null   int64
#  5   renda_anual         1541 non-null   float64
#  6   tipo_renda          1541 non-null   object
#  7   escolaridade        1541 non-null   object
#  8   estado_civil        1541 non-null   object
#  9   estilo_vida         1541 non-null   object
#  10  desempregado        1541 non-null   int64
#  11  celular             1541 non-null   int64
#  12  telefone_comercial  1541 non-null   int64
#  13  telefone            1541 non-null   int64
#  14  email_id            1541 non-null   int64
#  15  tipo_ocupação       1541 non-null   object
#  16  tamanho_familia     1541 non-null   int64
#  17  status              1541 non-null   int64
#  18  idade               1541 non-null   float64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 228.9+ KB

# %% [markdown]
# ## Transforme as colunas categóricas
#
#  Temos as seguintes colunas categóricas:
#
#  genero
#  carro
#  bens_propriedade
#  tipo_renda
#  escolaridade
#  estado_civil
#  estilo_vida
#  tipo_ocupação
#
#
#  Escolhemos tratar as colunas genero, carro e bens_propriedade com Label e as colunas escolaridade, estado_civil, estilo_vida, tipo_ocupação, tipo_renda com Dummies.
#
#  Nas colunas com tratamento tipo Dummies existiam varias opções dentro da mesma coluna e com esse tratamento dividiu as colunas contendo 0 para o caso de não condizer com a informação e 1 para o caso de condizer a informação.
#
#  Nos tratamentos com Label foi trocada a informação para as seguintes informações:
#
#  Y = 1;
#  N = 0;
#  M = 1;
#  F = 0;

# %%
colunas_label_encoder = ['genero', 'carro', 'bens_propriedade'] #Lista de colunas que serão codificadas com Label Encoder

df_tratado = df.copy()

#Tratamento com Label Encoder
label_encoder = LabelEncoder()
for coluna in colunas_label_encoder:
    df_tratado[coluna] = label_encoder.fit_transform(df_tratado[coluna])

 #Tratamento com Dummies/One Hot Encoding
df_tratado = pd.get_dummies(df_tratado, prefix_sep='_',columns=['tipo_renda',
                                                                'escolaridade',
                                                                'estado_civil',
                                                                'estilo_vida',
                                                                'tipo_ocupação'])
df_tratado.head().T
# Out:
#                                              0          1          2  \
# id                                     5008827    5009744    5009746
# genero                                       1          0          0
# carro                                        1          1          1
# bens_propriedade                             1          0          0
# filhos                                       0          0          0
# renda_anual                           180000.0   315000.0   315000.0
# desempregado                            365243       -586       -586
# celular                                      1          1          1
# telefone_comercial                           0          1          1
# telefone                                     0          1          1
# email_id                                     0          0          0
# tamanho_familia                              2          2          2
# status                                       1          1          1
# idade                                51.430137  37.142466  43.964384
# tipo_renda_Associado Comercial           False       True       True
# tipo_renda_CLT/PJ                        False      False      False
# tipo_renda_Pensionista                    True      False      False
# tipo_renda_Servidor do Estado            False      False      False
# escolaridade_Ensino fundamental          False      False      False
# escolaridade_Ensino medio                False      False      False
# escolaridade_Ensino superior              True       True       True
# escolaridade_Licenciatura                False      False      False
# escolaridade_Superior incompleto         False      False      False
# estado_civil_Casado                       True       True       True
# estado_civil_Divorciado                  False      False      False
# estado_civil_Solteiro                    False      False      False
# estado_civil_Uniao Estavel               False      False      False
# estado_civil_Viuvo                       False      False      False
# estilo_vida_Apartamento alugado          False      False      False
# estilo_vida_Apartamento cooperativo      False      False      False
# estilo_vida_Apartamento escritório       False      False      False
# estilo_vida_Apartamento municipal        False      False      False
# estilo_vida_Casa/Apartamento              True       True       True
# estilo_vida_Com os pais                  False      False      False
# tipo_ocupação_Auxiliar/Aprendiz          False      False      False
# tipo_ocupação_Contador                   False      False      False
# tipo_ocupação_Core staff                 False      False      False
# tipo_ocupação_Cozinha                    False      False      False
# tipo_ocupação_Funcionario                False      False      False
# tipo_ocupação_Garçom/Barmen              False      False      False
# tipo_ocupação_Gerente                    False      False      False
# tipo_ocupação_Imobiliaria                False      False      False
# tipo_ocupação_Limpeza                    False      False      False
# tipo_ocupação_Medicina                   False      False      False
# tipo_ocupação_Motorista                  False      False      False
# tipo_ocupação_Prefiro não informar        True       True       True
# tipo_ocupação_RH                         False      False      False
# tipo_ocupação_Secretária                 False      False      False
# tipo_ocupação_Segurança                  False      False      False
# tipo_ocupação_Serviço Privado            False      False      False
# tipo_ocupação_TI                         False      False      False
# tipo_ocupação_Tech                       False      False      False
# tipo_ocupação_Vendas                     False      False      False
#
#                                              3          4
# id                                     5009749    5009752
# genero                                       0          0
# carro                                        1          1
# bens_propriedade                             0          0
# filhos                                       0          0
# renda_anual                          172243.04   315000.0
# desempregado                              -586       -586
# celular                                      1          1
# telefone_comercial                           1          1
# telefone                                     1          1
# email_id                                     0          0
# tamanho_familia                              2          2
# status                                       1          1
# idade                                37.142466  37.142466
# tipo_renda_Associado Comercial            True       True
# tipo_renda_CLT/PJ                        False      False
# tipo_renda_Pensionista                   False      False
# tipo_renda_Servidor do Estado            False      False
# escolaridade_Ensino fundamental          False      False
# escolaridade_Ensino medio                False      False
# escolaridade_Ensino superior              True       True
# escolaridade_Licenciatura                False      False
# escolaridade_Superior incompleto         False      False
# estado_civil_Casado                       True       True
# estado_civil_Divorciado                  False      False
# estado_civil_Solteiro                    False      False
# estado_civil_Uniao Estavel               False      False
# estado_civil_Viuvo                       False      False
# estilo_vida_Apartamento alugado          False      False
# estilo_vida_Apartamento cooperativo      False      False
# estilo_vida_Apartamento escritório       False      False
# estilo_vida_Apartamento municipal        False      False
# estilo_vida_Casa/Apartamento              True       True
# estilo_vida_Com os pais                  False      False
# tipo_ocupação_Auxiliar/Aprendiz          False      False
# tipo_ocupação_Contador                   False      False
# tipo_ocupação_Core staff                 False      False
# tipo_ocupação_Cozinha                    False      False
# tipo_ocupação_Funcionario                False      False
# tipo_ocupação_Garçom/Barmen              False      False
# tipo_ocupação_Gerente                    False      False
# tipo_ocupação_Imobiliaria                False      False
# tipo_ocupação_Limpeza                    False      False
# tipo_ocupação_Medicina                   False      False
# tipo_ocupação_Motorista                  False      False
# tipo_ocupação_Prefiro não informar        True       True
# tipo_ocupação_RH                         False      False
# tipo_ocupação_Secretária                 False      False
# tipo_ocupação_Segurança                  False      False
# tipo_ocupação_Serviço Privado            False      False
# tipo_ocupação_TI                         False      False
# tipo_ocupação_Tech                       False      False
# tipo_ocupação_Vendas                     False      False

# %%
sns.jointplot(data=df, x='idade', y='renda_anual', hue='status')

# %%
#Gráfico de matriz de dispersão (pair plot)
sns.pairplot(df, hue='status')
plt.legend()
# Out:
# C:\Users\desir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #3 - Separação e normalização dos dados

# %%
# Remova a coluna status dos dados, extraindo as features na variável X
X = df_tratado.drop(['status'], axis = 1)
y_status = df['status']

# %%
#Separando em train e test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, # Conjunto de features
                                                    y_status, # Conjunto alvo
                                                    test_size=0.3, # Dividir o conjunto em x% para teste (se for float), x elementos para teste se inteiro
                                                    random_state=42, # Garantir a reprodutibilidade
                                                    stratify = y_status) # Garantir a estratificação balanceada (manter o desbalanceamento do dataset)

# %%
#confirmando o mantimento da proporcionalidade
print(f" Proporção y_status: \n{y_status.value_counts(normalize=True)}")
print(f" Proporção y_train: \n{y_train.value_counts(normalize=True)}")
print(f" Proporção y_test: \n{y_test.value_counts(normalize=True)}")
# Out:
#  Proporção y_status:
# status
# 0    0.889682
# 1    0.110318
# Name: proportion, dtype: float64
#  Proporção y_train:
# status
# 0    0.88961
# 1    0.11039
# Name: proportion, dtype: float64
#  Proporção y_test:
# status
# 0    0.889849
# 1    0.110151
# Name: proportion, dtype: float64

# %%
# Padronização/Normalizando dos dados utilizando o StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train) #Normalização nos dados de treino

# %%
X_test_std = scaler.transform(X_test) #Normalização nos dados de teste

# %%
print('Dados de treino->', X_train.shape[0])
print('Dados de teste ->', X_test.shape[0])
# Out:
# Dados de treino-> 1078
# Dados de teste -> 463

# %% [markdown]
# #4 - Machine Learning
# Analisando a performace dos dados nos seguintes modelos:
# - Decision Tree
# - Random Forest
# - AdaBoost
# - Gradient Boosting
# - XGBoost
# - LightGBM
#
# Para analisar esses modelos iremos utilizar as seguintes metricas:
# - Acurácia
# - Precisão
# - Recall
# - F1-Score
# - ROC-AUC

# %%
def treinamento_modelo(estimador, X_train, X_test, y_train):
    """
    Treina um modelo com os dados de treinamento e faz previsões com os dados de teste.

    Args:
        estimador: Um modelo de aprendizado de máquina (classificador/regressor).
        X_train: Dados de treinamento.
        X_test: Dados de teste.
        y_train: Rótulos de treinamento.

    Returns:
        y_pred: Rótulos previstos pelo modelo.
    """
    estimador.fit(X_train, y_train)
    y_pred = estimador.predict(X_test)

    return y_pred

# %%
def analise_relatorio_matriz_confusao(lista_modelos, X_train, X_test, y_train, y_test):
    """
    Esta função treina modelos, gera relatórios de classificação e plota matrizes de confusão para cada modelo.

    Args:
        lista_modelos: Uma lista de dicionários com informações sobre os modelos.
        X_train: Dados de treinamento.
        X_test: Dados de teste.
        y_train: Rótulos de treinamento.
        y_test: Rótulos de teste.
    """

    print(f"\n\n\n **** RELATÓRIO DOS MODELOS + MATRIZ DE CONFUSÃO ****\n")

    for mdl in lista_modelos:
        nome_do_modelo = mdl["nome_do_modelo"]
        estimador = mdl["estimador"]

        y_pred = treinamento_modelo(estimador, X_train, X_test, y_train)

        report = classification_report(y_test, y_pred) #Geração dos relatórios de classificação
        print(f"Relatório de classificação para {nome_do_modelo}:\n{report}\n {'='*60}")

        #Calculando e plotando a matriz de confusão
        cm = confusion_matrix(y_test, y_pred)
        plot_confusion_matrix(conf_mat=cm)
        plt.title(f"Matriz de Confusão para {nome_do_modelo}")
        plt.show()

# %%
def analise_curva_ROC_AUC(lista_modelos, X_train, X_test, y_train, y_test):
    """
    Esta função treina vários modelos e avalia seu desempenho usando métricas como acurácia, precisão, revocação e F1-score.
    Também plota a curva ROC-AUC e a matriz de confusão para cada modelo.

    Args:
        lista_modelos: Uma lista de dicionários contendo informações sobre os modelos a serem treinados.
        X_train: Dados de treinamento.
        X_test: Dados de teste.
        y_train: Rótulos de treinamento.
        y_test: Rótulos de teste.

    Returns:
        dict: Um dicionário com as métricas de desempenho de cada modelo.
    """

    print(f"\n\n\n **** RESULTADO DOS MODELOS + CURVA ROC-AUC ****\n")

    resposta = {}

    for mdl in lista_modelos:
        nome_do_modelo = mdl["nome_do_modelo"]
        estimador = mdl.get('estimador')

        y_pred = treinamento_modelo(estimador, X_train, X_test, y_train)

        fpr, tpr, thresholds = metrics.roc_curve(y_test, estimador.predict_proba(X_test)[:,1]) #Calculo da curva ROC

        # Cálculo das métricas de desempenho
        model_name = mdl.get('nome_do_modelo')
        accuracy = metrics.accuracy_score(y_test, y_pred)
        auc = metrics.roc_auc_score(y_test, estimador.predict(X_test))
        precision = metrics.precision_score(y_test, y_pred, average='weighted')
        recall = metrics.recall_score(y_test, y_pred, average='weighted')
        f1_score = metrics.f1_score(y_test, y_pred, average='weighted')

        plt.plot(fpr, tpr, label='%s ROC (AUC = %0.2f)' % (mdl.get('nome_do_modelo'), auc)) #Plotagem da curva ROC de cada modelo

        print(f"Modelo     : {nome_do_modelo}")
        print(f"Acurácia   : {accuracy:.5f}")
        print(f"Precisão   : {precision:.5f}")
        print(f"Revocação  : {recall:.5f}")
        print(f"F1 - Score : {f1_score:.5f}")
        print(f"ROC - AUC  : {auc:.5f}\n\n{'='*50}\n")

        resposta[mdl.get('nome_do_modelo')]  = {
            "Acurácia": accuracy,
            "Precisão": precision,
            "Revocação": recall,
            "f1_score": f1_score,
            "auc": auc,
        }

    #Plotagem da curva ROC geral
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taxa de Verdadeiro Positivo')
    plt.ylabel('Taxa de Falso Positivo')
    plt.title('CURVA ROC-AUC')
    plt.legend(loc="lower right")
    plt.show()

    return resposta

# %%
def dataframe_resposta(pipeline_resposta):
    """
    Cria um DataFrame a partir do resultado dos modelos contendo as métricas de desempenho de modelos.
    Args:
        pipeline_resposta: Um dicionário que contém métricas de desempenho para diferentes modelos.
    Returns:
        metricas_df: Um DataFrame que contém as métricas organizadas por modelo.
    """
    resp = []
    for modelo, modelo_metricas  in pipeline_resposta.items():
      metricas = []
      metricas.append(modelo)
      for metrica in modelo_metricas.values():
        metricas.append(metrica)
      resp.append(metricas)

    metricas_df = pd.DataFrame(resp, columns=['modelo'] + list(pipeline_resposta['Decision Tree'].keys()))
    return metricas_df

# %%
random_seed = 42 #garantir reprodutibilidade

#Lista de modelos utilizados para essa primeira análise
lista_modelos = [
  {
      "nome_do_modelo": "Decision Tree",
      "estimador": DecisionTreeClassifier(random_state=random_seed)
  },
  {
      "nome_do_modelo": "Random Forest",
      "estimador": RandomForestClassifier(random_state=random_seed)
  },
  {
      "nome_do_modelo": "AdaBoost",
      "estimador": AdaBoostClassifier(random_state=random_seed)
  },
  {
      "nome_do_modelo": "GradientBoosting",
      "estimador": GradientBoostingClassifier(random_state=random_seed)
  },
  {
      "nome_do_modelo": "XGBoost",
      "estimador": XGBClassifier(random_state=random_seed)
  },
  {
      "nome_do_modelo": "LightGBM",
      "estimador": lgb.LGBMClassifier(random_state=random_seed)
  },
]

# %% [markdown]
# #5 - Analisando os dados encontrados

# %%
#usando a função analise_relatorio_matriz_confusao para observar os dados por meio da matriz confusão
analise_relatorio_matriz_confusao(lista_modelos, X_train, X_test, y_train, y_test)
# Out:
#  **** RELATÓRIO DOS MODELOS + MATRIZ DE CONFUSÃO ****
#
# Relatório de classificação para Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       412
#            1       0.42      0.51      0.46        51
#
#     accuracy                           0.87       463
#    macro avg       0.68      0.71      0.69       463
# weighted avg       0.88      0.87      0.87       463
#
#  ============================================================
# Relatório de classificação para Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       412
#            1       0.92      0.43      0.59        51
#
#     accuracy                           0.93       463
#    macro avg       0.93      0.71      0.78       463
# weighted avg       0.93      0.93      0.92       463
#
#  ============================================================
# Relatório de classificação para AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94       412
#            1       0.75      0.06      0.11        51
#
#     accuracy                           0.89       463
#    macro avg       0.82      0.53      0.53       463
# weighted avg       0.88      0.89      0.85       463
#
#  ============================================================
# Relatório de classificação para GradientBoosting:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       412
#            1       0.69      0.18      0.28        51
#
#     accuracy                           0.90       463
#    macro avg       0.80      0.58      0.61       463
# weighted avg       0.88      0.90      0.87       463
#
#  ============================================================
# Relatório de classificação para XGBoost:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       412
#            1       0.74      0.49      0.59        51
#
#     accuracy                           0.92       463
#    macro avg       0.84      0.73      0.77       463
# weighted avg       0.92      0.92      0.92       463
#
#  ============================================================
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# Relatório de classificação para LightGBM:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       412
#            1       0.86      0.47      0.61        51
#
#     accuracy                           0.93       463
#    macro avg       0.90      0.73      0.79       463
# weighted avg       0.93      0.93      0.92       463
#
#  ============================================================

# %%
#usando a função nalise_curva_ROC_AUC para observar os dados por meio da curva ROC AUC
pipeline_resposta = analise_curva_ROC_AUC(lista_modelos, X_train, X_test, y_train, y_test)
# Out:
#  **** RESULTADO DOS MODELOS + CURVA ROC-AUC ****
#
# Modelo     : Decision Tree
# Acurácia   : 0.86825
# Precisão   : 0.88056
# Revocação  : 0.86825
# F1 - Score : 0.87377
# ROC - AUC  : 0.71121
#
# ==================================================
#
# Modelo     : Random Forest
# Acurácia   : 0.93305
# Precisão   : 0.93204
# Revocação  : 0.93305
# F1 - Score : 0.92206
# ROC - AUC  : 0.71326
#
# ==================================================
#
# Modelo     : AdaBoost
# Acurácia   : 0.89417
# Precisão   : 0.87941
# Revocação  : 0.89417
# F1 - Score : 0.85180
# ROC - AUC  : 0.52820
#
# ==================================================
#
# Modelo     : GradientBoosting
# Acurácia   : 0.90065
# Precisão   : 0.88305
# Revocação  : 0.90065
# F1 - Score : 0.87334
# ROC - AUC  : 0.58338
#
# ==================================================
#
# Modelo     : XGBoost
# Acurácia   : 0.92441
# Precisão   : 0.91691
# Revocação  : 0.92441
# F1 - Score : 0.91761
# ROC - AUC  : 0.73418
#
# ==================================================
#
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# Modelo     : LightGBM
# Acurácia   : 0.93305
# Precisão   : 0.92903
# Revocação  : 0.93305
# F1 - Score : 0.92421
# ROC - AUC  : 0.73044
#
# ==================================================

# %%
#Organização dos modelos e métricas
metricas_df=dataframe_resposta(pipeline_resposta)
metricas_df
# Out:
#              modelo  Acurácia  Precisão  Revocação  f1_score       auc
# 0     Decision Tree  0.868251  0.880564   0.868251  0.873772  0.711213
# 1     Random Forest  0.933045  0.932038   0.933045  0.922056  0.713259
# 2          AdaBoost  0.894168  0.879406   0.894168  0.851805  0.528198
# 3  GradientBoosting  0.900648  0.883055   0.900648  0.873343  0.583381
# 4           XGBoost  0.924406  0.916912   0.924406  0.917611  0.734176
# 5          LightGBM  0.933045  0.929032   0.933045  0.924208  0.730440

# %% [markdown]
# ## Validação do modelo
#
# A partir dos resultados das métricas dos modelos de classificação testados, ficou decidido que o modelo a ser utilizado será o LightGBM, tendo em vista seu melhor desempenho na métrica de Revocação, seguida pelo F1-Score. A escolha da métrica se deu em decorrência de optarmos por uma maior abrangência de clientes para recebimento do crédito.

# %% [markdown]
# #### Cross-Validation (Validação Cruzada)
#
# A fim de medir a generalização do modelo optado, utilizarmos a técnica de validação cruzada. Dessa forma, saberemos o quão preciso é o nosso modelo, ou seja o seu desempenho em um novo conjunto de dados

# %% [markdown]
# Utilizando o _cross_val_score_:

# %%
# Criando uma instância do modelo LightGBM

model_chosen = lgb.LGBMClassifier(random_state=random_seed)

# %%
# Lista de métricas a serem avaliadas durante a validação cruzada
metrics = ['accuracy', 'recall', 'precision', 'f1']

# Realização da validação cruzada usando o modelo LightGBM
rf_cross_val = cross_validate(
    model_chosen,
    X_train_std, 
    y_train,
    scoring=metrics, 
    cv=5 
)
# Out:
# [LightGBM] [Info] Number of positive: 95, number of negative: 767
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000324 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 884
# [LightGBM] [Info] Number of data points in the train set: 862, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110209 -> initscore=-2.088610
# [LightGBM] [Info] Start training from score -2.088610
# [LightGBM] [Info] Number of positive: 95, number of negative: 767
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000388 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 878
# [LightGBM] [Info] Number of data points in the train set: 862, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110209 -> initscore=-2.088610
# [LightGBM] [Info] Start training from score -2.088610
# [LightGBM] [Info] Number of positive: 95, number of negative: 767
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 887
# [LightGBM] [Info] Number of data points in the train set: 862, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110209 -> initscore=-2.088610
# [LightGBM] [Info] Start training from score -2.088610
# [LightGBM] [Info] Number of positive: 96, number of negative: 767
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 879
# [LightGBM] [Info] Number of data points in the train set: 863, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.111240 -> initscore=-2.078139
# [LightGBM] [Info] Start training from score -2.078139
# [LightGBM] [Info] Number of positive: 95, number of negative: 768
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 879
# [LightGBM] [Info] Number of data points in the train set: 863, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110081 -> initscore=-2.089913
# [LightGBM] [Info] Start training from score -2.089913

# %%
pd.DataFrame(rf_cross_val)
# Out:
#    fit_time  score_time  test_accuracy  test_recall  test_precision   test_f1
# 0  0.071003    0.006994       0.916667     0.333333        0.800000  0.470588
# 1  0.076550    0.008983       0.907407     0.333333        0.666667  0.444444
# 2  0.078852    0.009002       0.925926     0.458333        0.785714  0.578947
# 3  0.070551    0.010024       0.925581     0.391304        0.818182  0.529412
# 4  0.085490    0.008999       0.939535     0.625000        0.789474  0.697674

# %%
pd.DataFrame(rf_cross_val).describe().T
# Out:
#                 count      mean       std       min       25%       50%  \
# fit_time          5.0  0.076489  0.006164  0.070551  0.071003  0.076550
# score_time        5.0  0.008800  0.001104  0.006994  0.008983  0.008999
# test_accuracy     5.0  0.923023  0.011957  0.907407  0.916667  0.925581
# test_recall       5.0  0.428261  0.121448  0.333333  0.333333  0.391304
# test_precision    5.0  0.772007  0.060219  0.666667  0.785714  0.789474
# test_f1           5.0  0.544213  0.100437  0.444444  0.470588  0.529412
#
#                      75%       max
# fit_time        0.078852  0.085490
# score_time      0.009002  0.010024
# test_accuracy   0.925926  0.939535
# test_recall     0.458333  0.625000
# test_precision  0.800000  0.818182
# test_f1         0.578947  0.697674

# %% [markdown]
# Nota-se que nossos resultados foram bons, com a média da acurácia sendo 92% e a variância apenas 1%.

# %% [markdown]
# **Optimização de modelo(s)**
#
# - Optimização dos hiperparâmetros, pelo menos um (1) modelo
# - Demonstrar de forma clara quais os resultados obtidos
#
# Agora, iremos verificar se com outras combinações de parâmetros é possível otimizar a performance do nosso modelo.

# %%
model_chosen.fit(X_train, y_train)
y_pred = model_chosen.predict(X_test)

acc = accuracy_score(y_test, y_pred)

print(acc)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# 0.9330453563714903

# %% [markdown]
# Vamos começar entendendo os principais parâmetros do modelo.

# %%
pprint("Parâmetros do LightGBM:")
pprint(model_chosen.get_params())
# Out:
# 'Parâmetros do LightGBM:'
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': 42,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %% [markdown]
# - boosting_type (string, default='gbdt'): Define o tipo de boosting a ser utilizado.
#
# - num_leaves (int, default=31): Número máximo de folhas em uma árvore.
#
# - learning_rate (float, default=0.1): Taxa de aprendizado ou step size, controla a contribuição de cada árvore para a atualização do modelo durante o treinamento.
#
# - n_estimators (int, default=100): O número de árvores a serem treinadas.
#
# - subsample (float, default=1.0): Fração de amostras a serem usadas para ajustar cada árvore.
#
# - colsample_bytree (float, default=1.0): Fração de características (colunas) a serem usadas para ajustar cada árvore.
#
# - reg_alpha (float, default=0.0): Termo de regularização L1 nas folhas. Também conhecido como termo de penalização L1.
#
# - reg_lambda (float, default=0.0): Termo de regularização L2 nas folhas. Também conhecido como termo de penalização L2.

# %%
# Definindo o espaço de pesquisa para os hiperparâmetros escolhidos
params_grid = {
    'num_leaves': [20, 31, 40],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'reg_alpha': [0.0, 0.1, 0.5],
    'reg_lambda': [0.0, 0.1, 0.5], 
}

# %% [markdown]
# Partimos, agora, para o treinamento do GridSearch com os hiperparâmetros escolhidos para otimização.

# %%
grid_search = GridSearchCV(
    estimator=model_chosen, 
    param_grid = params_grid,
    scoring='accuracy',
    cv=3, 
    verbose=2,
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001278 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# GridSearchCV(cv=3, estimator=LGBMClassifier(random_state=42), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'num_leaves': [20, 31, 40],
#                          'reg_alpha': [0.0, 0.1, 0.5],
#                          'reg_lambda': [0.0, 0.1, 0.5],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='accuracy', verbose=2)

# %%
# Calculando a média dos resultados dos testes para todas as configurações de hiperparâmetros que foram experimentadas durante a pesquisa em grade 
print(grid_search.cv_results_['mean_test_score'].mean())
# Out:
# 0.9060213789680645

# %% [markdown]
# Após a pesquisa em grade, vamos verificar o dicionário com os melhores valores de hiperparâmetros encontrados durante o processo de busca.

# %%
# Melhor parâmetro grid_search
grid_search.best_params_
# Out:
# {'colsample_bytree': 0.9,
#  'learning_rate': 0.1,
#  'num_leaves': 40,
#  'reg_alpha': 0.1,
#  'reg_lambda': 0.1,
#  'subsample': 0.8}

# %% [markdown]
# Verificando e analisando os resultados da pesquisa em grade ao criar um DataFrame contendo os resultados da validação cruzada e, em seguida, calcular estatísticas descritivas para esses resultados, facilitando a análise do desempenho do modelo em diferentes configurações de hiperparâmetros.

# %%
cvs = pd.DataFrame(grid_search.cv_results_)

cvs.T
# Out:
#                                                                       0    \
# mean_fit_time                                                    1.038249
# std_fit_time                                                     0.036365
# mean_score_time                                                  0.009675
# std_score_time                                                   0.002369
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.0
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       1    \
# mean_fit_time                                                    1.219037
# std_fit_time                                                      0.09037
# mean_score_time                                                   0.00768
# std_score_time                                                   0.000627
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.0
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       2    \
# mean_fit_time                                                    0.869706
# std_fit_time                                                     0.092249
# mean_score_time                                                  0.008848
# std_score_time                                                   0.002257
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.0
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       3    \
# mean_fit_time                                                    0.853406
# std_fit_time                                                     0.065777
# mean_score_time                                                  0.005669
# std_score_time                                                   0.000941
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       4    \
# mean_fit_time                                                    0.733653
# std_fit_time                                                      0.01398
# mean_score_time                                                  0.006679
# std_score_time                                                   0.000627
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       5    \
# mean_fit_time                                                    0.645512
# std_fit_time                                                     0.068032
# mean_score_time                                                   0.00532
# std_score_time                                                    0.00097
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.1
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       6    \
# mean_fit_time                                                    0.641031
# std_fit_time                                                     0.094546
# mean_score_time                                                  0.006487
# std_score_time                                                   0.001123
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.5
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       7    \
# mean_fit_time                                                    0.590601
# std_fit_time                                                     0.023748
# mean_score_time                                                  0.009514
# std_score_time                                                   0.003742
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.5
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       8    \
# mean_fit_time                                                    0.661421
# std_fit_time                                                     0.004027
# mean_score_time                                                  0.007509
# std_score_time                                                   0.001874
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.5
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                                                                       9    \
# mean_fit_time                                                    0.791992
# std_fit_time                                                     0.096941
# mean_score_time                                                  0.006849
# std_score_time                                                   0.001664
# param_colsample_bytree                                                0.8
# param_learning_rate                                                  0.01
# param_num_leaves                                                       20
# param_reg_alpha                                                       0.1
# param_reg_lambda                                                      0.0
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.0...
# split0_test_score                                                0.888889
# split1_test_score                                                0.891365
# split2_test_score                                                0.888579
# mean_test_score                                                  0.889611
# std_test_score                                                   0.001247
# rank_test_score                                                       487
#
#                         ...  \
# mean_fit_time           ...
# std_fit_time            ...
# mean_score_time         ...
# std_score_time          ...
# param_colsample_bytree  ...
# param_learning_rate     ...
# param_num_leaves        ...
# param_reg_alpha         ...
# param_reg_lambda        ...
# param_subsample         ...
# params                  ...
# split0_test_score       ...
# split1_test_score       ...
# split2_test_score       ...
# mean_test_score         ...
# std_test_score          ...
# rank_test_score         ...
#
#                                                                       719  \
# mean_fit_time                                                    1.928866
# std_fit_time                                                     0.013778
# mean_score_time                                                  0.008197
# std_score_time                                                   0.001267
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.1
# param_reg_lambda                                                      0.5
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.908333
# split1_test_score                                                0.916435
# split2_test_score                                                0.924791
# mean_test_score                                                   0.91652
# std_test_score                                                   0.006719
# rank_test_score                                                       136
#
#                                                                       720  \
# mean_fit_time                                                    1.822924
# std_fit_time                                                     0.019298
# mean_score_time                                                  0.008026
# std_score_time                                                   0.001228
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.0
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.908333
# split1_test_score                                                0.908078
# split2_test_score                                                0.924791
# mean_test_score                                                  0.913734
# std_test_score                                                   0.007819
# rank_test_score                                                       232
#
#                                                                       721  \
# mean_fit_time                                                    1.497726
# std_fit_time                                                      0.26907
# mean_score_time                                                  0.007842
# std_score_time                                                   0.002096
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.0
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.908333
# split1_test_score                                                0.908078
# split2_test_score                                                0.924791
# mean_test_score                                                  0.913734
# std_test_score                                                   0.007819
# rank_test_score                                                       232
#
#                                                                       722  \
# mean_fit_time                                                    1.052572
# std_fit_time                                                     0.038877
# mean_score_time                                                  0.005849
# std_score_time                                                   0.000471
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.0
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.908333
# split1_test_score                                                0.908078
# split2_test_score                                                0.924791
# mean_test_score                                                  0.913734
# std_test_score                                                   0.007819
# rank_test_score                                                       232
#
#                                                                       723  \
# mean_fit_time                                                    0.877755
# std_fit_time                                                     0.030847
# mean_score_time                                                  0.006853
# std_score_time                                                   0.001553
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.905556
# split1_test_score                                                0.908078
# split2_test_score                                                0.933148
# mean_test_score                                                  0.915594
# std_test_score                                                   0.012455
# rank_test_score                                                       166
#
#                                                                       724  \
# mean_fit_time                                                    0.818903
# std_fit_time                                                     0.038753
# mean_score_time                                                  0.008195
# std_score_time                                                    0.00119
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.905556
# split1_test_score                                                0.908078
# split2_test_score                                                0.933148
# mean_test_score                                                  0.915594
# std_test_score                                                   0.012455
# rank_test_score                                                       166
#
#                                                                       725  \
# mean_fit_time                                                    0.951252
# std_fit_time                                                     0.072069
# mean_score_time                                                  0.019682
# std_score_time                                                   0.018636
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.1
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.905556
# split1_test_score                                                0.908078
# split2_test_score                                                0.933148
# mean_test_score                                                  0.915594
# std_test_score                                                   0.012455
# rank_test_score                                                       166
#
#                                                                       726  \
# mean_fit_time                                                    1.030808
# std_fit_time                                                     0.007965
# mean_score_time                                                  0.007353
# std_score_time                                                   0.002105
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.5
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.910864
# split2_test_score                                                0.924791
# mean_test_score                                                  0.916514
# std_test_score                                                   0.005981
# rank_test_score                                                       157
#
#                                                                       727  \
# mean_fit_time                                                    0.868256
# std_fit_time                                                     0.028169
# mean_score_time                                                  0.006351
# std_score_time                                                   0.000862
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.5
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.910864
# split2_test_score                                                0.924791
# mean_test_score                                                  0.916514
# std_test_score                                                   0.005981
# rank_test_score                                                       157
#
#                                                                       728
# mean_fit_time                                                    0.669311
# std_fit_time                                                      0.06039
# mean_score_time                                                  0.006682
# std_score_time                                                   0.001312
# param_colsample_bytree                                                1.0
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.5
# param_reg_lambda                                                      0.5
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 1.0, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.910864
# split2_test_score                                                0.924791
# mean_test_score                                                  0.916514
# std_test_score                                                   0.005981
# rank_test_score                                                       157
#
# [17 rows x 729 columns]

# %%
cvs.describe().T
# Out:
#                    count        mean         std       min         25%  \
# mean_fit_time      729.0    1.110726    0.447987  0.572674    0.818810
# std_fit_time       729.0    0.065256    0.079515  0.000389    0.017688
# mean_score_time    729.0    0.007838    0.004115  0.004342    0.006015
# std_score_time     729.0    0.002093    0.003942  0.000002    0.000710
# split0_test_score  729.0    0.902218    0.009869  0.888889    0.888889
# split1_test_score  729.0    0.902003    0.011204  0.888579    0.891365
# split2_test_score  729.0    0.913844    0.018158  0.888579    0.888579
# mean_test_score    729.0    0.906021    0.012137  0.888683    0.889611
# std_test_score     729.0    0.006715    0.004732  0.000146    0.001247
# rank_test_score    729.0  330.851852  178.420066  1.000000  178.000000
#
#                           50%         75%         max
# mean_fit_time        1.002884    1.229722    4.029131
# std_fit_time         0.042745    0.078859    0.749757
# mean_score_time      0.006853    0.008364    0.060021
# std_score_time       0.001225    0.002077    0.059084
# split0_test_score    0.905556    0.911111    0.916667
# split1_test_score    0.899721    0.908078    0.927577
# split2_test_score    0.924791    0.927577    0.933148
# mean_test_score      0.910949    0.915589    0.923014
# std_test_score       0.006838    0.010711    0.017348
# rank_test_score    361.000000  487.000000  697.000000

# %%
cvs.sort_values('rank_test_score').head().T
# Out:
#                                                                       473  \
# mean_fit_time                                                    1.141273
# std_fit_time                                                     0.019314
# mean_score_time                                                   0.00703
# std_score_time                                                   0.001416
# param_colsample_bytree                                                0.9
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.1
# param_reg_lambda                                                      0.1
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 0.9, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.927577
# split2_test_score                                                0.927577
# mean_test_score                                                  0.923014
# std_test_score                                                   0.006452
# rank_test_score                                                         1
#
#                                                                       472  \
# mean_fit_time                                                    1.144226
# std_fit_time                                                     0.038607
# mean_score_time                                                  0.005856
# std_score_time                                                   0.000242
# param_colsample_bytree                                                0.9
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.1
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.9
# params                  {'colsample_bytree': 0.9, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.927577
# split2_test_score                                                0.927577
# mean_test_score                                                  0.923014
# std_test_score                                                   0.006452
# rank_test_score                                                         1
#
#                                                                       471  \
# mean_fit_time                                                    1.165916
# std_fit_time                                                     0.054528
# mean_score_time                                                  0.006696
# std_score_time                                                   0.000854
# param_colsample_bytree                                                0.9
# param_learning_rate                                                   0.1
# param_num_leaves                                                       40
# param_reg_alpha                                                       0.1
# param_reg_lambda                                                      0.1
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.9, 'learning_rate': 0.1...
# split0_test_score                                                0.913889
# split1_test_score                                                0.927577
# split2_test_score                                                0.927577
# mean_test_score                                                  0.923014
# std_test_score                                                   0.006452
# rank_test_score                                                         1
#
#                                                                       195  \
# mean_fit_time                                                    1.254297
# std_fit_time                                                     0.190742
# mean_score_time                                                  0.009005
# std_score_time                                                   0.000817
# param_colsample_bytree                                                0.8
# param_learning_rate                                                   0.1
# param_num_leaves                                                       31
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.5
# param_subsample                                                       0.8
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.1...
# split0_test_score                                                0.916667
# split1_test_score                                                0.922006
# split2_test_score                                                0.930362
# mean_test_score                                                  0.923011
# std_test_score                                                   0.005636
# rank_test_score                                                         4
#
#                                                                       197
# mean_fit_time                                                    1.038565
# std_fit_time                                                     0.046796
# mean_score_time                                                  0.005846
# std_score_time                                                   0.000238
# param_colsample_bytree                                                0.8
# param_learning_rate                                                   0.1
# param_num_leaves                                                       31
# param_reg_alpha                                                       0.0
# param_reg_lambda                                                      0.5
# param_subsample                                                       1.0
# params                  {'colsample_bytree': 0.8, 'learning_rate': 0.1...
# split0_test_score                                                0.916667
# split1_test_score                                                0.922006
# split2_test_score                                                0.930362
# mean_test_score                                                  0.923011
# std_test_score                                                   0.005636
# rank_test_score                                                         4

# %%
cvs[cvs.rank_test_score == 1].sort_values('mean_fit_time').iloc[0].params
# Out:
# {'colsample_bytree': 0.9,
#  'learning_rate': 0.1,
#  'num_leaves': 40,
#  'reg_alpha': 0.1,
#  'reg_lambda': 0.1,
#  'subsample': 1.0}

# %% [markdown]
# Treinando o modelo LGBMClassifier com os melhores parâmetros encontrados durante o __GridSearch__.

# %%
model_gs = lgb.LGBMClassifier(**grid_search.best_params_)

# %%
model_gs
# Out:
# LGBMClassifier(colsample_bytree=0.9, num_leaves=40, reg_alpha=0.1,
#                reg_lambda=0.1, subsample=0.8)

# %%
model_gs.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006650 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(colsample_bytree=0.9, num_leaves=40, reg_alpha=0.1,
#                reg_lambda=0.1, subsample=0.8)

# %%
y_pred_gs = model_gs.predict(X_test)

# %% [markdown]
# Calculamos, agora, a acurácia, a qual teve como resultado 0.93 aproximadamente, resultando em um bom resultado.

# %%
acc_grid = accuracy_score(y_test, y_pred_gs)
print(acc_grid)
# Out:
# 0.9265658747300216

# %% [markdown]
# Agora, partiremos para a aplicação do __RandomizedSearchCV__, começando com o seu treinamento.

# %%
from sklearn.model_selection import RandomizedSearchCV

random_search = RandomizedSearchCV(
    estimator=model_chosen,
    param_distributions=params_grid,
    n_iter=100,
    cv=3,
    verbose=2,
    n_jobs=-1
)

# %%
random_search.fit(X_train, y_train)
print(random_search.cv_results_['mean_test_score'].mean())
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000974 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.9066459816362324

# %%
# Verificando os melhores parâmetros após o treinamento
random_search.best_params_
# Out:
# {'subsample': 1.0,
#  'reg_lambda': 0.1,
#  'reg_alpha': 0.1,
#  'num_leaves': 31,
#  'learning_rate': 0.1,
#  'colsample_bytree': 0.8}

# %% [markdown]
# Treinando o modelo LGBMClassifier com os melhores parâmetros encontrados durante o __RandomizedSearchCV__.

# %%
model_rs = lgb.LGBMClassifier(**random_search.best_params_)
model_rs
# Out:
# LGBMClassifier(colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)

# %%
model_rs.fit(X_train, y_train)
y_pred_rs = model_rs.predict(X_test)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# Salvando a acurácia com o RandomizedSearch
acc_random = accuracy_score(y_test, y_pred_rs)

# %%
# Realizando as comparações de acurácias
print("Comparação das Acurácias: ")
print('Acurácia sem Otimização:         ', np.round(acc, 3))
print('Acurácia com GridSearchCV:       ', np.round(acc_grid, 3))
print('Acurácia com RandomizedSearchCV: ', np.round(acc_random, 3))
# Out:
# Comparação das Acurácias:
# Acurácia sem Otimização:          0.933
# Acurácia com GridSearchCV:        0.927
# Acurácia com RandomizedSearchCV:  0.929

# %% [markdown]
# **Conclusões**
# - Explicar os principais achados (comparação de métricas e modelos)
# - Próximos passos
# - Potenciais ganhos para o negócio

# %% [markdown]
# - No cenário sem otimização, o modelo alcançou uma acurácia de 0.933.
# - No cenário com GridSearchCV, a acurácia é ligeiramente menor, indicando que os melhores parâmetros encontrados pela pesquisa em grade não resultaram em um modelo com desempenho melhor do que o modelo não otimizado.
# - No cenário com RandomizedSearchCV, a acurácia é igual à do GridSearchCV, indicando que, no caso específico dos parâmetros testados pelo RandomizedSearchCV, ele não encontrou uma combinação melhor do que a encontrada pelo GridSearchCV.
#
# Possíveis motivos:
# - A acurácia é uma métrica simples e pode não ser suficiente para capturar completamente a qualidade do modelo;
# - É importante considerar o tempo e os recursos computacionais necessários para a execução da pesquisa em grade ou busca aleatória.

# %% [markdown]
# A análise comparativa entre um modelo sem otimização e modelos otimizados usando GridSearchCV e RandomizedSearchCV revelou que a acurácia do modelo não otimizado era igual ou ligeiramente superior à dos modelos otimizados. Isso indica que os melhores parâmetros encontrados pela pesquisa em grade e busca aleatória não resultaram em uma melhoria significativa no desempenho do modelo em termos de acurácia.
#
# Essa conclusão sugere que, no contexto específico deste problema de aprovação de crédito, a acurácia pode não ser a métrica mais sensível ou apropriada para avaliar o desempenho do modelo. Outras métricas, como sensibilidade, especificidade, valor preditivo positivo ou negativo, podem fornecer uma visão mais completa da eficácia do modelo na identificação de bons e maus pagadores.
#
# Próximos passos:
#
# Avaliação de outras métricas: Como mencionado, a acurácia é uma métrica simples e não é suficiente para avaliar completamente a qualidade do modelo. Considere a avaliação de outras métricas, como sensibilidade, especificidade, valor preditivo positivo e negativo, área sob a curva ROC,  entre outras. Isso pode fornecer uma visão mais abrangente do desempenho do modelo.
# Business Metrics: Além das métricas de desempenho do modelo, avaliar como as decisões de crédito afetam os resultados de negócios, como inadimplência, lucratividade e satisfação do cliente. Essas métricas são cruciais para determinar o impacto real das decisões de crédito no sucesso financeiro da instituição.
# Interpretabilidade: Dependendo das regulamentações e da necessidade de transparência, pode ser preferível um modelo mais simples, mesmo que a acurácia seja ligeiramente menor.
#
# Possíveis ganhos para o negócio:
#
# Redução de Riscos: Um modelo mais preciso ou estrategicamente otimizado pode ajudar a reduzir o risco de inadimplência, minimizando as perdas de crédito e melhorando a saúde financeira da instituição.
# Melhor Experiência do Cliente: Ao otimizar as decisões de crédito, é possível oferecer melhores condições e aprovações mais precisas, o que pode melhorar a experiência do cliente e a satisfação.
# Cumprimento de Regulamentos: Modelos mais precisos podem ajudar a garantir que a instituição cumpra regulamentos e práticas éticas de concessão de crédito, evitando problemas legais.
# Eficiência Operacional: A otimização pode resultar em processos de tomada de decisão mais eficientes, economizando tempo e recursos da instituição.
# Vantagem Competitiva: Uma abordagem mais avançada e estratégica para a concessão de crédito pode dar à instituição uma vantagem competitiva no mercado.

# %% [markdown]
# A partir desse trecho, tentamos desenvolver as demais métricas após a otimização do modelo, mas não conseguimos validar esses processos e dados devido a limitação de tempo, portanto, não consideramos essas informações no projeto e estamos apresentando no notebook final apenas para conhecimento do professor.

# %%
grid_search = GridSearchCV(
    estimator=model_chosen, 
    param_grid = params_grid,
    scoring='recall',
    cv=3, 
    verbose=2,
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000416 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# GridSearchCV(cv=3, estimator=LGBMClassifier(random_state=42), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'num_leaves': [20, 31, 40],
#                          'reg_alpha': [0.0, 0.1, 0.5],
#                          'reg_lambda': [0.0, 0.1, 0.5],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='recall', verbose=2)

# %%
# Calculando a média dos resultados dos testes para todas as configurações de hiperparâmetros que foram experimentadas durante a pesquisa em grade 
print(grid_search.cv_results_['mean_test_score'].mean())
# Out:
# 0.2892161710849948

# %%
rec_grid = recall_score(y_test, y_pred_gs)
print(rec_grid)
# Out:
# 0.45098039215686275

# %%
grid_search = GridSearchCV(
    estimator=model_chosen, 
    param_grid = params_grid,
    scoring='precision',
    cv=3, 
    verbose=2,
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000397 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# GridSearchCV(cv=3, estimator=LGBMClassifier(random_state=42), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'num_leaves': [20, 31, 40],
#                          'reg_alpha': [0.0, 0.1, 0.5],
#                          'reg_lambda': [0.0, 0.1, 0.5],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='precision', verbose=2)

# %%
# Calculando a média dos resultados dos testes para todas as configurações de hiperparâmetros que foram experimentadas durante a pesquisa em grade 
print(grid_search.cv_results_['mean_test_score'].mean())
# Out:
# 0.51774194242748

# %%
pre_grid = precision_score(y_test, y_pred_gs)
print(pre_grid)
# Out:
# 0.7931034482758621

# %%
grid_search = GridSearchCV(
    estimator=model_chosen, 
    param_grid = params_grid,
    scoring='f1',
    cv=3, 
    verbose=2,
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 729 candidates, totalling 2187 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001908 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# GridSearchCV(cv=3, estimator=LGBMClassifier(random_state=42), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'num_leaves': [20, 31, 40],
#                          'reg_alpha': [0.0, 0.1, 0.5],
#                          'reg_lambda': [0.0, 0.1, 0.5],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='f1', verbose=2)

# %%
# Calculando a média dos resultados dos testes para todas as configurações de hiperparâmetros que foram experimentadas durante a pesquisa em grade 
print(grid_search.cv_results_['mean_test_score'].mean())
# Out:
# 0.2892161710849948

# %%
f1_grid = f1_score(y_test, y_pred_gs)
print(f1_grid)
# Out:
# 0.5750000000000001

# %%
# Salvando a recall  com o RandomizedSearch
rec_random = recall_score(y_test, y_pred_rs)

print(rec_random)
# Out:
# 0.45098039215686275

# %%
# Salvando a f1  com o RandomizedSearch
f1_random = f1_score(y_test, y_pred_rs)

print( f1_random)
# Out:
# 0.5822784810126583

# %%
# Salvando a precision  com o RandomizedSearch
pre_random = precision_score(y_test, y_pred_rs)

print( pre_random)
# Out:
# 0.8214285714285714

# %%
model_chosen.fit(X_train, y_train)
y_pred = model_chosen.predict(X_test)

rec = recall_score (y_test, y_pred)
f1 = f1_score (y_test, y_pred)
pre = precision_score (y_test, y_pred)

print(rec, f1, pre)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 119, number of negative: 959
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 1078, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110390 -> initscore=-2.086768
# [LightGBM] [Info] Start training from score -2.086768
# 0.47058823529411764 0.6075949367088607 0.8571428571428571

# %%
# Realizando as comparações de Recall
print("Comparação das rec: ")
print('Recall sem Otimização:         ', np.round(rec, 3))
print('Recall com GridSearchCV:       ', np.round(rec_grid, 3))
print('Recall com RandomizedSearchCV: ', np.round(rec_random, 3))
# Out:
# Comparação das rec:
# Recall sem Otimização:          0.471
# Recall com GridSearchCV:        0.451
# Recall com RandomizedSearchCV:  0.582

# %%
# Realizando as comparações de F1
print("Comparação das f1: ")
print('f1 sem Otimização:         ', np.round(f1, 3))
print('f1 com GridSearchCV:       ', np.round(f1_grid, 3))
print('f1 com RandomizedSearchCV: ', np.round(f1_random, 3))
# Out:
# Comparação das f1:
# f1 sem Otimização:          0.608
# f1 com GridSearchCV:        0.575
# f1 com RandomizedSearchCV:  0.582

# %%
# Realizando as comparações de Precision
print("Comparação das Pre: ")
print('Pre sem Otimização:         ', np.round(pre, 3))
print('Pre com GridSearchCV:       ', np.round(pre_grid, 3))
print('Pre com RandomizedSearchCV: ', np.round(pre_random, 3))
# Out:
# Comparação das Pre:
# Pre sem Otimização:          0.857
# Pre com GridSearchCV:        0.793
# Pre com RandomizedSearchCV:  0.821
